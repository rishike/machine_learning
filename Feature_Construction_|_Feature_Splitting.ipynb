# %% [markdown]
# <a href="https://colab.research.google.com/github/rishike/machine_learning/blob/master/Feature_Construction_%7C_Feature_Splitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression

import seaborn as sns

# %%
df = pd.read_csv('train.csv')[['Age', 'Pclass', 'SibSp', 'Parch', 'Survived']]

# %%
df.head()
# Out:
#     Age  Pclass  SibSp  Parch  Survived
# 0  22.0       3      1      0         0
# 1  38.0       1      1      0         1
# 2  26.0       3      0      0         1
# 3  35.0       1      1      0         1
# 4  35.0       3      0      0         0

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#     Age  Pclass  SibSp  Parch  Survived
# 0  22.0       3      1      0         0
# 1  38.0       1      1      0         1
# 2  26.0       3      0      0         1
# 3  35.0       1      1      0         1
# 4  35.0       3      0      0         0

# %%
df.head()
# Out:
#     Age  Pclass  SibSp  Parch  Survived
# 0  22.0       3      1      0         0
# 1  38.0       1      1      0         1
# 2  26.0       3      0      0         1
# 3  35.0       1      1      0         1
# 4  35.0       3      0      0         0

# %%
X = df.iloc[:,0:4]
y = df.iloc[:,-1]

# %%
X
# Out:
#       Age  Pclass  SibSp  Parch
# 0    22.0       3      1      0
# 1    38.0       1      1      0
# 2    26.0       3      0      0
# 3    35.0       1      1      0
# 4    35.0       3      0      0
# ..    ...     ...    ...    ...
# 885  39.0       3      0      5
# 886  27.0       2      0      0
# 887  19.0       1      0      0
# 889  26.0       1      0      0
# 890  32.0       3      0      0
#
# [714 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 714, dtype: int64

# %%
np.mean(cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=20))
# Out:
# np.float64(0.6933333333333332)

# %% [markdown]
# Applying Feature Construction

# %%
X['Family_Size'] = X['SibSp'] + X['Parch'] + 1

# %%
X.head()
# Out:
#     Age  Pclass  SibSp  Parch  Family_Size
# 0  22.0       3      1      0            2
# 1  38.0       1      1      0            2
# 2  26.0       3      0      0            1
# 3  35.0       1      1      0            2
# 4  35.0       3      0      0            1

# %%
def familyType(num):
  if num == 1:
    return 0 # alone
  elif num > 1 and num <= 4:
    return 1 # small family
  else:
    return 2 # large family

# %%
X['Family_Type'] = X['Family_Size'].apply(familyType)

# %%
X.head()
# Out:
#     Age  Pclass  SibSp  Parch  Family_Size
# 0  22.0       3      1      0            2
# 1  38.0       1      1      0            2
# 2  26.0       3      0      0            1
# 3  35.0       1      1      0            2
# 4  35.0       3      0      0            1

# %%
X.drop(columns=['SibSp', 'Parch', 'Family_Size'], inplace=True)

# %%
X.head()
# Out:
#     Age  Pclass
# 0  22.0       3
# 1  38.0       1
# 2  26.0       3
# 3  35.0       1
# 4  35.0       3

# %%
np.mean(cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=20))
# Out:
# np.float64(0.6961111111111111)

# %% [markdown]
# Feature Splitting

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df['Title'] = df['Name'].str.split(', ', expand=True)[1].str.split('.', expand=True)[0]

# %%
df['Title']
# Out:
# 0        Mr
# 1       Mrs
# 2      Miss
# 3       Mrs
# 4        Mr
#        ...
# 886     Rev
# 887    Miss
# 888    Miss
# 889      Mr
# 890      Mr
# Name: Title, Length: 891, dtype: object

# %%
df[['Title', 'Name']]
# Out:
#     Title                                               Name
# 0      Mr                            Braund, Mr. Owen Harris
# 1     Mrs  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2    Miss                             Heikkinen, Miss. Laina
# 3     Mrs       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4      Mr                           Allen, Mr. William Henry
# ..    ...                                                ...
# 886   Rev                              Montvila, Rev. Juozas
# 887  Miss                       Graham, Miss. Margaret Edith
# 888  Miss           Johnston, Miss. Catherine Helen "Carrie"
# 889    Mr                              Behr, Mr. Karl Howell
# 890    Mr                                Dooley, Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df.groupby('Title')['Survived'].mean().sort_values(ascending=False)
# Out:
# Title
# Lady            1.000000
# Ms              1.000000
# Sir             1.000000
# Mme             1.000000
# the Countess    1.000000
# Mlle            1.000000
# Mrs             0.792000
# Miss            0.697802
# Master          0.575000
# Major           0.500000
# Col             0.500000
# Dr              0.428571
# Mr              0.156673
# Capt            0.000000
# Jonkheer        0.000000
# Don             0.000000
# Rev             0.000000
# Name: Survived, dtype: float64

# %%
df['Is_Married'] = 0
df['Is_Married'].loc[df['Title'] == 'Mrs'] == 1
# Out:
# 1      False
# 3      False
# 8      False
# 9      False
# 15     False
#        ...
# 871    False
# 874    False
# 879    False
# 880    False
# 885    False
# Name: Is_Married, Length: 125, dtype: bool
